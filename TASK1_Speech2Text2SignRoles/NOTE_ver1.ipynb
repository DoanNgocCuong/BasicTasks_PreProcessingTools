# %% [markdown]
# API GPT4o: sk-proj-hrHNTMh5L6sxEs669JfqT3BlbkFJvyPqaiPjlIX4hYbHrcPT

# %% [markdown]
# ## CẬP NHẬT TIẾN ĐỘ:
#
# Link: [TASK 1](https://www.notion.so/cuongvc/Sales-report-720188c72dc34b1198bc6cfb447807a8?pvs=11)
#
# ```
# Here is the extracted text from the image:
#
# ---
#
# **Sales report**
#
# 🔥 **Thực trạng**: Hiện tại sales manager và sales leaders phải nghe nhiều log call của nhân viên để:
# + Theo dõi đánh giá tình hình bán hàng và khả năng bán hàng của nhân viên
# + Kịp thời phát hiện các trường hợp xử lý không tốt/khách hàng không hài lòng gây ảnh hưởng tới thương hiệu
# + Tìm hiểu nguyên nhân cho các giai đoạn có kết quả bán hàng tốt/chưa tốt.
#
# 🚫 **Vấn đề**: Mỗi lần nghe mất rất nhiều thời gian và không hiệu quả.
# ⇒ cần giảm thời gian phải nghe call của sales managers và sales leaders.
#
# 💡 **Giải pháp**:
# Chuyển tất cả audio ⇒ text
# Dùng LLM để tổng hợp text thành định dạng dễ đọc, phân rõ vai [khách hàng] [nhân viên tư vấn]
# Đưa lên 1 dạng UI để xem
# Dùng LLM để tổng hợp thành báo cáo có insight
#
# 🔧 **Danh sách công nghệ**:
# Whisper internal API:
# LLM internal: APIs bên Sơn
#
# ---
#
# Let me know if you need any further assistance with this information!
#
# ```
#
# - 11hr - 12hr:
# ```
# - Cái Speech to Text em run nó chạy rùi anh ạ.
# - Còn cái Phân vai em run thử thì bị lỗi: "Method Not Allowed". Anh check giúp em xem hay có bị lỗi HTTP, API hay gì không
# với ạ.
# ```
#
# - 4hr-7h:
# ```
# Anh ui, Em báo cáo tiến độ 2 ạ:
# 1.
# - UI cơ bản, các step cơ bản cho 1 audio em đã xong rồi ạ.
# - Step 1: Speech to text, em xài API anh đưa, với xài GPT4o đều ra cùng kết quả và GIỐNG VỚI VÍ DỤ trong Notion anh gửi
# (bị lỗi 1 số chữ như "LaLaLa School, Nghiền Mỳ Gõ, ...")
# - Step 2: thì em phân đoạn được rùi, cơ mà nó CHƯA ĐƯỢC MƯỢT, CHUẨN như ví dụ trong NOTION anh gửi.
# (1. Của Notion thì từ Text nó được chuẩn sửa lỗi chính tả => của em thì chưa
# 2. Của Notion thì nó được phân đoạn đúng vai trò => của em thi thoảng bị lệch thì phải, em đang TỐI ƯU PROMPT hơn).
#
# - cái API 1 em run được,
# - còn API 2 không được (có gì anh check lại giúp em cái API 2 với ạ :v ) - hiện em đang xài API chatGPT4 cá nhân để thay thế API 2.
# ```
#
#
# - [Next Step] Báo cáo đầu ngày 28/06: Hôm nay em dự kiến:
# 1. Là build lên web UI(UI như nào thì hợp lý để xem PHÂN VAI).
# 2. ANH GỬI LẠI CHO EM cái API bên Team, (xem kết quả của API anh gửi chắc sẽ PHÂN VAI tốt giống với cái ví dụ anh gửi em)
# Trong trường hợp kết quả PHÂN VAI không được tốt như ví dụ -> có thể phải tinh chỉnh Prompt hoặc tìm giải pháp khác.
# 3. Thao tác với 100 calls từ file .csv
# 4. Chiều thi xong tầm 14h em qua công ty.
#
# -> Future: Phân tích INSIGHT, ... Xem trực tiếp "TEXT PHÂN VAI" ngay trong app được không? Kết quả phân vai ổn chưa? UI dễ xài hơn đẹp hơn được không?
#
#
# Hello anh, em báo cáo cuối ngày 28/06/2024 ạ. (OBS bị hỏng nên em quay chay demo ạ).
# 1. UI cơ bản đã ổn.
# 2. Prompting em đang prompt thêm.
# - Vấn đề lỗi chính ta, prompt đã bỏ được.
# - Vấn đề PHÂN VAI LỖI, mai em chỉnh prompt thêm
# (ANH CÓ GỢI Ý GÌ PHẦN PROMPT cho em thì em xin ạ 😁).
# 3. 100 videos .csv thì em chưa động vô kịp.
# (Anh gửi lại cho em cái account với ạ, account này: cuongvc.rd@stepup.edu.vn/123456a@
# bị lỗi ko đúng anh ạ).
#
# Thank anh ạ.

# %% [markdown]
# ### 1. Down Outline Client: https://getoutline.org/vi/get-started/#step-3
#
# - VPN key (cài outline client, add key vào và sử dụng). VPN sẽ dùng để call tới các APIs nội bộ
# `
#     ss://Y2hhY2hhMjAtaWV0Zi1wb2x5MTMwNTpTUlRjdWsxdjYxckt3SUhTRTVLM3lz@42.96.42.50:8655/?outline=1
# `
#
# Hướng dẫn: [How To Run Your Own VPN Server With Outline And DigitalOcean](https://www.youtube.com/watch?v=_pB4UtJVb_Q&t=405s)

# %% [markdown]
# ### 2. Run API Speech to Text (phải dùng VPN)
#
# ```bash
#
# curl -v --location "http://42.96.42.156:6112/api/v1/asr/audio" ^
#     --header "accept: application/json" ^
#     --form "token=su-ewiuwernmvf1ifmdsafajkdfaiwwe" ^
#     --form "language=vi" ^
#     --form "file=@D:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\Product_THECOACH\TASK1_SPEECH2TEXT2SIGNROLES\out-0966000394-1204-20240626-114630-1719377190.171536.mp3"
#
# ```
#
#
# Output:
#
# ```
# C:\Users\User>curl -v --location "http://42.96.42.156:6112/api/v1/asr/audio" ^
# More?     --header "accept: application/json" ^
# More?     --form "token=su-ewiuwernmvf1ifmdsafajkdfaiwwe" ^
# More?     --form "language=vi" ^
# More?     --form "file=@D:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\Product_THECOACH\TASK1\out-0966000394-1204-20240626-114630-1719377190.171536.mp3"
# *   Trying 42.96.42.156:6112...
# * Connected to 42.96.42.156 (42.96.42.156) port 6112
# > POST /api/v1/asr/audio HTTP/1.1
# > Host: 42.96.42.156:6112
# > User-Agent: curl/8.7.1
# > accept: application/json
# > Content-Length: 2081298
# > Content-Type: multipart/form-data; boundary=------------------------q2PFpU3S0UnIz2VEMowL2p
# > Expect: 100-continue
# >
# < HTTP/1.1 100 Continue
# <
# * upload completely sent off: 2081298 bytes
# < HTTP/1.1 200 OK
# < date: Thu, 27 Jun 2024 11:11:15 GMT
# < server: uvicorn
# < content-length: 11293
# < content-type: application/json
# <
#
# C:\Users\User>
#
# ```

# %% [markdown]
# ```
# curl -X POST "https://api.openai.com/v1/audio/transcriptions" ^
# -H "Authorization: Bearer sk-proj-hrHNTMh5L6sxEs669JfqT3BlbkFJvyPqaiPjlIX4hYbHrcPT" ^
# -H "Content-Type: multipart/form-data" ^
# -F "file=@D:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\Product_THECOACH\TASK1\out-0966000394-1204-20240626-114630-1719377190.171536.mp3" ^
# -F "model=whisper-1" ^
# -F "language=vi"
#
#
# ```

# %% [markdown]
# ### 3. Text -> to PHÂN VAI
#
# ```
# - LLM internal model (private)
#
#     curl --location 'http://31.12.82.146:6003/overbloom/api/v1/chat_completion' \
#     --header 'Content-Type: application/json' \
#     --header 'Authorization: Bearer 8OfpF)l+Dh|gNCY&oV/^LZAHW"c3tGRu' \
#     --data '{
#     "prompt": [
#     {"role": "user", "content": "Xin chào"}
#     ]
#     }'
#
# ```
# => BUG: `Method Not Allowed`: Điều này có thể do phương thức HTTP không đúng.
# => Hãy kiểm tra lại tài liệu API hoặc liên hệ với đội ngũ phát triển để xác minh rằng phương thức HTTP đúng cho endpoint này là POST.
# => Chuyển từ xài API của team sang API OPENAI
#
#
# ```bash
# @echo off
# set TRANSCRIPTION=Hello, dạ em chào anh, em là trường BNAP The Coach em à. Thì có hẹn với mình ở liên hệ lại sau ấy à. Thế em có thấy là mình có bấm quan tâm về cái phần là chương trình học 1-1 của bên em đúng không anh? Ờ, đúng rồi. Vâng, về cái phần thông tin thì chắc là mình cũng có từng tham khảo qua về trên app ...
#
# :: Escape double quotes for JSON payload
# set "TRANSCRIPTION=%TRANSCRIPTION:"=\"%"
#
# curl --location "https://api.openai.com/v1/chat/completions" ^
#     --header "Content-Type: application/json" ^
#     --header "Authorization: Bearer sk-proj-hrHNTMh5L6sxEs669JfqT3BlbkFJvyPqaiPjlIX4hYbHrcPT" ^
#     --data "{\"model\": \"gpt-3.5-turbo\", \"messages\": [{\"role\": \"user\", \"content\": \"Phân vai các đoạn hội thoại:\\n\\n%TRANSCRIPTION%\"}]}"
#
#
# ```
#
# Output:
# ```
#
# C:\Users\User>@echo off
# set TRANSCRIPTION=Hello, dạ em chào anh, em là trường BNAP The Coach em à. Thì có hẹn với mình ở liên hệ lại sau ấy à. Thế em có thấy là mình có bấm quan tâm về cái phần là chương trình học 1-1 của bên em đúng không anh? Ờ, đúng rồi. Vâng, về cái phần thông tin thì chắc là mình cũng có từng tham khảo qua về trên app ...
#
# :: Escape double quotes for JSON payload
# set "TRANSCRIPTION=%TRANSCRIPTION:"=\"%"
#
# curl --location "https://api.openai.com/v1/chat/completions" ^
# More?     --header "Content-Type: application/json" ^
# More?     --header "Authorization: Bearer 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" ^
# More?     --data "{\"model\": \"gpt-3.5-turbo\", \"messages\": [{\"role\": \"user\", \"content\": \"Phân vai các đoạn hội thoại giữa 'Nhân viên bán hàng' và 'Khách hàng':\\n\\n%TRANSCRIPTION%\"}]}"
# {
#   "id": "chatcmpl-9eheatKA3iq1kpaewmRqAaOZ134y4",
#   "object": "chat.completion",
#   "created": 1719487952,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Nhân viên bán hàng: Xin chào anh/chị, em có thể giúp gì cho anh/chị hôm nay?\n\nKhách hàng: Xin chào, tôi đặt hẹn với một nhân viên bên đây. Liên hệ sau nhé.\n\nNhân viên bán hàng: Dạ vâng, anh/chị quan tâm đến chương trình học 1-1 của chúng tôi phải không?\n\nKhách hàng: Vâng, đúng rồi. Tôi đã tham khảo thông tin trên ứng dụng của bạn và muốn tìm hiểu thêm về chương trình đó.\n\nNhân viên bán hàng: Vậy anh/chị muốn biết thêm thông tin gì về chương trình đó? Chúng tôi sẽ cung cấp cho anh/chị đầy đủ thông tin cần thiết."
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 179,
#     "completion_tokens": 241,
#     "total_tokens": 420
#   },
#   "system_fingerprint": null
# }
#
#
# ```

# %% [markdown]
# ### Deploy

# %% [markdown]
# 1. WSL 2 backend, x86_64: Sử dụng nếu bạn có Windows 10 phiên bản 19044 hoặc cao hơn, hoặc Windows 11 với phần cứng x86_64.
# ```
# wsl --install
# wsl --set-default-version 2
# ```
# 2. Cài đặt một bản phân phối Linux (như Ubuntu) và sau đó tiến hành cài đặt Docker Desktop: `wsl --install -d Ubuntu-22.04`
# 3. Cài Docker

# %% [markdown]
# 3. Xây dựng Docker image : `docker build -t my-flask-app .` (Đảm bảo các file Dockerfile và requirements.txt)
#
# Chạy lại Docker container để kiểm tra: `docker run -p 5000:5000 my-flask-app`
#
# => Output:
#
# ```
#
# D:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\Product_THECOACH\TASK1_Speech2Text2SignRoles\deploy>docker run -p 5000:5000 my-flask-app
#  * Serving Flask app 'app' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://172.17.0.2:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 527-810-520
#
# ```
# Truy cập vào đây: http://localhost:5000/

# %% [markdown]
# [Chia sẻ 3 cách deploy ứng dụng Python Web App - Mì AI](https://www.youtube.com/watch?v=AC6Da-xXFyo)
#
# ### So sánh tổng quan
#
# | Phương pháp      | Chi phí       | Tốc độ triển khai | Dễ sử dụng     | Tài nguyên | Bảo mật | Thời gian chạy |
# |------------------|---------------|-------------------|----------------|------------|---------|----------------|
# | PC + Ngrok       | Miễn phí      | Nhanh chóng       | Rất dễ         | Giới hạn   | Thấp    | Giới hạn       |
# | VPS              | Tùy chọn gói  | Trung bình        | Khó hơn        | Tùy chọn   | Cao     | Không giới hạn |
# | Cloud App Platform | Miễn phí/rẻ  | Nhanh chóng       | Rất dễ         | Giới hạn   | Trung bình | Giới hạn      |
#
# ### Khuyến nghị
#
# - **Nhanh và miễn phí**: Nếu bạn cần một giải pháp nhanh chóng để thử nghiệm và không cần độ bảo mật cao, PC + Ngrok là một lựa chọn tốt.
# - **Linh hoạt và bảo mật**: Nếu bạn cần kiểm soát hoàn toàn và bảo mật cao, VPS là lựa chọn tốt nhất, nhưng yêu cầu kỹ năng quản lý hệ thống.
# - **Dễ sử dụng và tự động**: Nếu bạn muốn một giải pháp dễ sử dụng và tự động triển khai, Heroku hoặc Vercel là lựa chọn phù hợp, đặc biệt với các dự án nhỏ và thử nghiệm.
#
#
#
# ---
# Để bảo mật API key và token trong ứng dụng Flask khi triển khai lên Heroku hoặc bất kỳ nền tảng nào khác, bạn nên sử dụng biến môi trường (environment variables) để lưu trữ thông tin nhạy cảm

# %% [markdown]
# Heroku:
# 1. Cài Heroku CLI: https://devcenter.heroku.com/articles/heroku-cli#install-the-heroku-cli
# - `heroku --version`
# 2. Đăng nhập: `heroku login` - cài Salesforce Authenticator trên Phone.
#
# 3. Tạo một ứng dụng mới: `heroku create my-flask-app`
#
# 4. Thiết lập biến môi trường  cho API key:
#      ```
#      heroku config:set STT_TOKEN=su-ewiuwernmvf1ifmdsafajkdfaiwwe
#      heroku config:set OPENAI_API_KEY=sk-proj-hrHNTMh5L6sxEs669JfqT3BlbkFJvyPqaiPjlIX4hYbHrcPT
#      ```
#
# ### Bước 5: Chuẩn bị và triển khai ứng dụng Flask lên Heroku
#
# 1. **Khởi tạo git repository (nếu chưa làm)**:
#    - Chuyển đến thư mục dự án của bạn và chạy các lệnh:
#      ```powershell
#      cd "D:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\Product_THECOACH\TASK1_Speech2Text2SignRoles\deploy"
#      git init
#      git add .
#      git commit -m "Initial commit"
#      ```
#
# 2. **Đăng nhập vào Docker registry của Heroku**:
#    - Chạy lệnh:
#      ```powershell
#      heroku container:login
#      ```
#
# 3. **Push Docker image lên Heroku**:
#    - Chạy lệnh:
#      ```powershell
#      heroku container:push web
#      ```
#
# 4. **Phát hành ứng dụng trên Heroku**:
#    - Chạy lệnh:
#      ```powershell
#      heroku container:release web
#      ```
#
# 5. **Mở ứng dụng trên trình duyệt**:
#    - Chạy lệnh:
#      ```powershell
#      heroku open
#      ```
#
# ### Nội dung file `app.py` sử dụng biến môi trường
#
# ```python
# from flask import Flask, render_template, request, jsonify
# import requests
# import json
# import os
#
# app = Flask(__name__)
#
# @app.route('/')
# def index():
#     return render_template('index.html')
#
# @app.route('/speech_to_text', methods=['POST'])
# def speech_to_text():
#     if 'file' not in request.files:
#         print('No file part')
#         return jsonify({'success': False, 'msg': 'No file part'})
#
#     file = request.files['file']
#     if file.filename == '':
#         print('No selected file')
#         return jsonify({'success': False, 'msg': 'No selected file'})
#
#     try:
#         stt_url = "http://42.96.42.156:6112/api/v1/asr/audio"
#         stt_token = os.getenv('STT_TOKEN')
#         headers = {"accept": "application/json"}
#         files = {
#             "token": (None, stt_token),
#             "language": (None, "vi"),
#             "file": (file.filename, file, 'audio/mpeg')
#         }
#
#         print('Sending request to speech-to-text API')
#         stt_response = requests.post(stt_url, headers=headers, files=files, timeout=60)
#         stt_response.raise_for_status()
#         stt_result = stt_response.json()
#         print('Received response from speech-to-text API:', stt_result)
#         if stt_result["success"]:
#             transcription = stt_result['result']['text']
#             return jsonify({'success': True, 'transcription': transcription})
#         else:
#             return jsonify({'success': False, 'msg': stt_result['msg']})
#     except requests.exceptions.RequestException as e:
#         print('Request failed:', e)
#         return jsonify({'success': False, 'msg': str(e)})
#
# @app.route('/assign_roles', methods=['POST'])
# def assign_roles():
#     transcription = request.json.get('transcription')
#     if not transcription:
#         print('No transcription provided')
#         return jsonify({'success': False, 'msg': 'No transcription provided'})
#
#     try:
#         openai_url = "https://api.openai.com/v1/chat/completions"
#         openai_token = os.getenv('OPENAI_API_KEY')
#         openai_headers = {
#             "Content-Type": "application/json",
#             "Authorization": f"Bearer {openai_token}"
#         }
#
#         prompt = f"""
#         - Đọc kỹ toàn bộ nội dung để hiểu rõ cuộc hội thoại. Việc này sẽ giúp phân vai chính xác hơn.
#         - Phân vai các đoạn hội thoại giữa 'Nhân viên bán hàng' và 'Khách hàng'.
#         - Chú ý đặc biệt đến cách xưng hô (anh, chị, em, ...) để duy trì đúng việc phân vai xuyên suốt cuộc hội thoại.
#         - Đảm bảo sử dụng nhất quán cách xưng hô cho mỗi vai trong toàn bộ cuộc đối thoại.
#
#         Ngoài ra:
#         - Sửa các lỗi chính tả trong lời thoại nếu có.
#         - Tuyệt đối không thêm hoặc bớt thông tin nào.
#
#         Đoạn hội thoại:
#         {transcription}
#
#         Vui lòng định dạng đầu ra như sau:
#         Nhân viên bán hàng: [lời thoại]
#         Khách hàng: [lời thoại]
#
#         Lưu ý: Duy trì cách xưng hô nhất quán cho mỗi vai trong toàn bộ cuộc đối thoại.
#         """
#
#         openai_data = {
#             "model": "gpt-4-turbo",
#             "messages": [
#                 {
#                     "role": "user",
#                     "content": prompt
#                 }
#             ]
#         }
#
#         print('Sending request to OpenAI API')
#         openai_response = requests.post(openai_url, headers=openai_headers, data=json.dumps(openai_data))
#         openai_response.raise_for_status()
#         openai_result = openai_response.json()
#         print('Received response from OpenAI API:', openai_result)
#         if 'choices' in openai_result and len(openai_result['choices']) > 0:
#             assigned_roles = openai_result['choices'][0]['message']['content']
#             print('Assigned roles:', assigned_roles)
#             return jsonify({'success': True, 'roles': assigned_roles})
#         else:
#             return jsonify({'success': False, 'msg': 'No response from OpenAI.'})
#     except requests.exceptions.RequestException as e:
#         print('Request failed:', e)
#         return jsonify({'success': False, 'msg': str(e)})
#
# if __name__ == '__main__':
#     app.run(host='0.0.0.0', port=5000, debug=True)
# ```
#
# ### File `Dockerfile`
#
# ```Dockerfile
# FROM python:3.9-slim
#
# WORKDIR /app
#
# COPY requirements.txt .
# RUN pip install --no-cache-dir -r requirements.txt
#
# COPY . .
#
# EXPOSE 5000
#
# CMD ["python", "app.py"]
# ```
#
# ### File `requirements.txt`
#
# ```plaintext
# Flask==2.0.1
# requests==2.26.0
# Werkzeug==2.0.3
# ```
#
# ### File `Procfile`
#
# ```plaintext
# web: python app.py
# ```
#
# ### File `heroku.yml`
#
# ```yaml
# build:
#   docker:
#     web: Dockerfile
# ```
#
# Nếu bạn gặp bất kỳ vấn đề nào hoặc cần thêm trợ giúp, hãy cho tôi biết!
